# %%
import requests
import json
from tqdm import tqdm

import pandas as pd

# %%
# set the API endpoint
api = 'https://geoscience.data.qld.gov.au/api/action/'
# construct our query
query = api + 'package_search?q=seismic&rows=1000'
# make the get request and store it in the response object
response = requests.get(query)
# view the payload as JSON
json_response = response.json()

#and get a count of results we can retrieve
total_results = json_response['result']['count']

#hack without understanding/researching the api too much
getloop = int(total_results/1000) + 1

results_list = []
for i in range(getloop):
    loopq = query + "&start=" + str(i*1000)
    response = requests.get(query)
    json_response = response.json()
    
    results_list.append(json_response)

# print the GeoJSON for the results
#for index, dataset in enumerate(json_response['result']['results']):
    #print(dataset.get('GeoJSONextent'))
    #print(index)

# %%
#look at a result for the structure
results_list[0]['result']['results'][887]
# Out:
# {'license_title': 'Creative Commons Attribution',
#  'maintainer': None,
#  'creator': 'geological-survey-of-queensland',
#  'relationships_as_object': [],
#  'private': False,
#  'maintainer_email': None,
#  'num_tags': 1,
#  'organization': {'description': "GSQ unlocks the value of geoscience data to enable industry success.\r\n\r\nGSQ plays a key role in improving understanding of Queensland's resource potential and attracting exploration and investment in the resources sector.\r\n\r\n#Exploration attraction\r\nGSQ creates and distributes exploration and resource investment information and presents at national and international events. We also raise awareness of Queensland's prospectivity through new geoscientific information and manage industry exploration grants.\r\n\r\n#Mineral and energy geoscience\r\nGSQ collects and provides geoscience data, information and advice on Queensland’s mineral resources and resource potential through a range of [geoscience projects and initiatives](https://www.business.qld.gov.au/industries/mining-energy-water/resources/geoscience-information/geoscience-projects).\r\n\r\nWe support the state’s energy industry by collecting and providing geoscience data and advice on coal, coal seam gas, petroleum, including unconventional petroleum, oil shale and geothermal energy.\r\n\r\n#Geoscience products and services\r\nWe make mineral and energy geoscience data and information available to industry and government through our publications, maps and digital data products.\r\n\r\nThe Exploration Data Centre (EDC) at Brisbane and the John Campbell Miles Drill Core Storage Facility at Mount Isa house geoscience data and information dating back to the mid-1800s. The collections include [drill core and cuttings](https://www.business.qld.gov.au/industries/mining-energy-water/resources/geoscience-information/exploration-incentives/drillcore) from the Department of Natural Resources, Mines and Energy (DNRME) and company exploration programs, and samples from GSQ mapping fieldwork. The EDC also provides [HyLoggerTM scanning services](https://www.business.qld.gov.au/industries/mining-energy-water/resources/geoscience-information/exploration-incentives/drillcore).\r\n\r\n#Online services\r\nOnline access is available for many of our products, through [MinesOnlineMaps](https://www.business.qld.gov.au/industries/mining-energy-water/resources/minerals-coal/online-services/minesonlinemaps), [QDEX Reports](https://www.business.qld.gov.au/industries/mining-energy-water/resources/minerals-coal/online-services/qdex-reports), [QDEX Data](https://www.business.qld.gov.au/industries/mining-energy-water/resources/minerals-coal/online-services/qdex-data) and [QSpatial](https://www.business.qld.gov.au/running-business/support-assistance/mapping-data-imagery/data/qspatial).",
#   'created': '2019-05-13T06:53:09.682491',
#   'title': 'Geological Survey of Queensland',
#    'datastore_active': False,
#    'id': 'geo-doc491262-cr090940',
#    'size': None,
#    'resource:format': 'ZIP',
#    'resource:size': '2.24 KB',
#    'download_url': 'https://geoscience.data.qld.gov.au/dataset/636431df-1507-4946-9b38-d9f8fd234c16/resource/geo-doc491262-cr090940/download/%252FReport%25252f90940%25252fDocument%25252f491262%25252f90940.zip',
#    'state': 'active',
#    'last_modified': None,
#    'hash': '',
#    'description': '',
#    'format': 'ZIP',
#    'mimetype_inner': None,
#    'url_type': None,
#    'mimetype': None,
#    'cache_url': None,
#    'resource:access_rights': 'http://linked.data.gov.au/def/data-access-rights/open',
#    'name': 'CR090940 Report Geometry',
#    'created': '2020-08-03T09:09:30.202461',
#    'url': 'https://gsq-prod-ckan-horizon-public.s3.ap-southeast-2.amazonaws.com/Report%2f90940%2fDocument%2f491262%2f90940.zip',
#    'resource:resource_type': 'ASSOCIATED_DOCUMENT',
#    'position': 0,
#    'revision_id': '5481faab-cbed-442d-9517-7940eebd7cc1',
#    'resource_type': None},
#   {'resource:description': 'INTERPRETATION REPORT',
#    'cache_last_updated': None,
#    'package_id': '636431df-1507-4946-9b38-d9f8fd234c16',
#    'datastore_contains_all_records_of_source_file': 'False',
#    'datastore_active': False,
#    'id': 'geo-doc955137-cr090940',
#    'size': None,
#    'resource:format': 'PDF',
#    'resource:size': '1.31 MB',
#    'state': 'active',
#    'last_modified': None,
#    'hash': '',
#    'description': '',
#    'format': 'PDF',
#    'mimetype_inner': None,
#    'url_type': None,
#    'mimetype': None,
#    'cache_url': None,
#    'resource:access_rights': 'http://linked.data.gov.au/def/data-access-rights/open',
#    'name': 'INTERPRETATION REPORT',
#    'created': '2020-08-03T09:09:30.202468',
#    'url': 'https://gsq-horizon.s3-ap-southeast-2.amazonaws.com/QDEX/90940/cr_90940_1.pdf',
#    'resource:resource_type': 'ASSOCIATED_DOCUMENT',
#    'position': 1,
#    'revision_id': '5481faab-cbed-442d-9517-7940eebd7cc1',
#    'resource_type': None},
#   {'resource:description': 'APPENDIX A - ACQUISITION REPORT - GEOKINETICS',
#    'cache_last_updated': None,
#    'package_id': '636431df-1507-4946-9b38-d9f8fd234c16',
#    'datastore_contains_all_records_of_source_file': 'False',
#    'datastore_active': False,
#    'id': 'geo-doc955139-cr090940',
#    'size': None,
#    'resource:format': 'PDF',
#    'resource:size': '4.29 MB',
#    'state': 'active',
#    'last_modified': None,
#    'hash': '',
#    'description': '',
#    'format': 'PDF',
#    'mimetype_inner': None,
#    'url_type': None,
#    'mimetype': None,
#    'cache_url': None,
#    'resource:access_rights': 'http://linked.data.gov.au/def/data-access-rights/open',
#    'name': 'APPENDIX A - ACQUISITION REPORT - GEOKINETICS',
#    'created': '2020-08-03T09:09:30.202471',
#    'url': 'https://gsq-horizon.s3-ap-southeast-2.amazonaws.com/QDEX/90940/cr_90940_2.pdf',
#    'resource:resource_type': 'ASSOCIATED_DOCUMENT',
#    'position': 2,
#    'revision_id': '5481faab-cbed-442d-9517-7940eebd7cc1',
#    'resource_type': None},
#   {'resource:description': 'APPENDIX B - PROCESSING REPORT - EARTH SIGNAL',
#    'cache_last_updated': None,
#    'package_id': '636431df-1507-4946-9b38-d9f8fd234c16',
#    'datastore_contains_all_records_of_source_file': 'False',
#    'datastore_active': False,
#    'id': 'geo-doc955140-cr090940',
#    'size': None,
#    'resource:format': 'PDF',
#    'resource:size': '5.35 MB',
#    'state': 'active',
#    'last_modified': None,
#    'hash': '',
#    'description': '',
#    'format': 'PDF',
#    'mimetype_inner': None,
#    'url_type': None,
#    'mimetype': None,
#    'cache_url': None,
#    'resource:access_rights': 'http://linked.data.gov.au/def/data-access-rights/open',
#    'name': 'APPENDIX B - PROCESSING REPORT - EARTH SIGNAL',
#    'created': '2020-08-03T09:09:30.202497',
#    'url': 'https://gsq-horizon.s3-ap-southeast-2.amazonaws.com/QDEX/90940/cr_90940_3.pdf',
#    'resource:resource_type': 'ASSOCIATED_DOCUMENT',
#    'position': 3,
#    'revision_id': '5481faab-cbed-442d-9517-7940eebd7cc1',
#    'resource_type': None},
#   {'resource:description': 'This derived machine-readable file contains text extracted by Optical Character Recognition (OCR) from report CR090940 - ATP 685, QGC KERMODE 2D 2013 SEISMIC SURVEY, FINAL REPORT. Because of the age and condition of some documents and the software tools available, the OCR may not recognise certain characters and words correctly. Please use due care when using full text search or analysing the file contents, as these anomalies may affect results.',
#    'cache_last_updated': None,
#    'package_id': '636431df-1507-4946-9b38-d9f8fd234c16',
#    'datastore_contains_all_records_of_source_file': 'False',
#    'datastore_active': False,
#    'id': 'd7f9b607-5b88-4ef4-8d61-6fa3f79ebadb',
#    'size': 13783795,
#    'resource:format': 'DOCX',
#    'state': 'active',
#    'hash': '',
#    'description': 'This derived machine-readable file contains text extracted by Optical Character Recognition (OCR) from report CR090940 - ATP 685, QGC KERMODE 2D 2013 SEISMIC SURVEY, FINAL REPORT. Because of the age and condition of some documents and the software tools available, the OCR may not recognise certain characters and words correctly. Please use due care when using full text search or analysing the file contents, as these anomalies may affect results.',
#    'format': 'DOCX',
#    'last_modified': None,
#    'url_type': 'upload',
#    'mimetype': None,
#    'cache_url': None,
#    'name': 'OCR extract of report CR090940',
#    'created': '2021-03-15T01:03:56.668463',
#    'url': 'https://geoscience.data.qld.gov.au/dataset/636431df-1507-4946-9b38-d9f8fd234c16/resource/d7f9b607-5b88-4ef4-8d61-6fa3f79ebadb/download/cr_90940_ocr.docx',
#    'mimetype_inner': None,
#    'position': 4,
#    'revision_id': '5481faab-cbed-442d-9517-7940eebd7cc1',
#    'resource_type': None}],
#  'earth_science_data_category': [],
#  'num_resources': 5,
#  'tags': [{'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'Report',
#    'id': '127a5d03-e989-4f0d-a844-1ec0d200032a',
#    'name': 'Report'}],
#  'resource_authority_permit': 'ATP 685',
#  'dataset_start_date': '2015-03-27',
#  'groups': [],
#  'license_id': 'cc-by',
#  'isopen': True,
#  'relationships_as_subject': [],
#  'dataset_completion_date': '2015-03-27',
#  'name': 'cr090940',
#  'commodity': ['http://linked.data.gov.au/def/geo-commodities/coal-bed-methane'],
#  'was_generated_by': 'SS095367',
#  'url': None,
#  'notes': 'ATP 685, QGC KERMODE 2D 2013 SEISMIC SURVEY, FINAL REPORT',
#  'owner_org': '1461ac2d-f813-4c97-9e3b-3900a23b0ecb',
#  'georesource_report_type': 'http://linked.data.gov.au/def/georesource-report/seismic-survey-report-final',
#  'title': 'ATP 685, QGC KERMODE 2D 2013 SEISMIC SURVEY, FINAL REPORT',
#  'revision_id': '598a67a3-a6b5-4ada-bcae-19f5ab60745d',
#  'extra:identifier': 'CR090940',
#  'open_file_date': '2016-12-21'}

# %%
#each one has organisation - don't really need
#id, , author, spatial, type is useful
#resources - a list of dicts, 
#eg resource:description:
#resource description dictionary
#a resource id, resource:size, resource:, download_url, name, url, resource_type etc

# %%
#will try and make a dataframe
#but using the batched results, getting the ids
#turning the resource dictionaries into dataframes, concatenating
#then concatenating back at the end

# %%
result_ids = []
for batch in tqdm(results_list, total=len(results_list) ):
    results = batch['result']['results']
    for r in results:
        rid = r['id']
        rauthor = r['author']
        rspatial = r['spatial']
        rtype = r['type']
        
        if len(r['resources']) > 0:
            part_list = []
            for part in r['resources']:
                #df = pd.DataFrame.from_dict(part)
                df = pd.DataFrame([part])
                df['rid'] = rid
                df['rauthor'] = rauthor
                df['rspatial'] = rspatial
                df['type'] = rtype
                part_list.append(df)
                allparts = pd.concat(part_list)
                
            result_ids.append(allparts)

dfDatasets = pd.concat(result_ids)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [28:32<00:00, 342.43s/it]

# %%
dfDatasets.to_csv(r'H:\GSQ_Seimisc_Datasets.csv')

# %%
#this is what a default query would look like
query_default = api + 'package_search?q=seismic

response = requests.get(query_default)
json_response = response.json()

print(json_response['result']['count'])
print(len(json_response['result']['results']) )
for x in json_response['result']['results']:
    print(x["id"])
# Out:
# 10
# 4267
# aaa7c8c3-d69b-4ae6-bc4b-2542301b7e6e
# 39bc2c60-d727-4383-b82d-6af7fdf8cf7b
# 2f3d761c-6506-438a-934a-87e48cc8d25e
# 8a1f58c4-2e61-44a5-a573-794396652ea6
# 55a1c3a1-107f-4a65-9bec-bef9e6eb8d6b
# 8157408f-83af-4515-9279-f502ae16c155
# 37a2fb0c-49c5-444a-a7da-4947ae9dad94
# 3897db72-0d38-4f11-aad4-8fa8907d20bb
# 4d5ae331-3cfb-4042-a4b5-1955c135cace
# 30b6b5fc-ba25-4bfe-a76b-c35d72ba07e0

# %% [markdown]
# Check how many are of type seismic, not report

# %%
dfDatasets.loc[dfDatasets['type'] == 'seismic']['rid'].unique().size
# Out:
# 8
